# %%
from pybit.unified_trading import HTTP
import pandas as pd
from time import sleep
from my_stuff import EmailSenderInfo, BybitTestKeys

# %%
api_key = BybitTestKeys.api_key
secret_key = BybitTestKeys.secret_key

# %%
session = HTTP(
    testnet = True,
    api_key = api_key,
    api_secret = secret_key
)

# %%
session.get_account_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'marginMode': 'ISOLATED_MARGIN',
#   'updatedTime': '1709234629000',
#   'unifiedMarginStatus': 4,
#   'dcpStatus': 'OFF',
#   'timeWindow': 10,
#   'smpGroup': 0,
#   'isMasterTrader': False,
#   'spotHedgingStatus': 'OFF'}}

# %%
session.get_open_orders(category = "linear", symbol = "BTCUSDT", orderID = '2a71af82-03ce-4706-b52d-9e2b33d63999')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': 'c0075de0-96c8-4b66-b692-115e5786f4a6%3A1709480338689%2C54ff7a3c-591e-4802-a8a1-ddaec3f34de3%3A1709480338082',
#   'category': 'linear',
#   'list': [{'symbol': 'BTCUSDT',
#     'orderType': 'Market',
#     'orderLinkId': '',
#     'slLimitPrice': '0',
#     'orderId': 'c0075de0-96c8-4b66-b692-115e5786f4a6',
#     'cancelType': 'UNKNOWN',
#     'avgPrice': '',
#     'stopOrderType': 'Stop',
#     'lastPriceOnCreated': '62258.7',
#     'orderStatus': 'Untriggered',
#     'createType': 'CreateByStopOrder',
#     'takeProfit': '',
#     'cumExecValue': '0',
#     'tpslMode': '',
#     'smpType': 'None',
#     'triggerDirection': 2,
#     'blockTradeId': '',
#     'isLeverage': '',
#     'rejectReason': 'EC_NoError',
#     'price': '0',
#     'orderIv': '',
#     'createdTime': '1709480338689',
#     'tpTriggerBy': '',
#     'positionIdx': 1,
#     'timeInForce': 'IOC',
#     'leavesValue': '0',
# ...

# %%
session.get_order_history(category = "linear", orderID = '2a71af82-03ce-4706-b52d-9e2b33d63999')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '8753f5cb-bc2f-47d2-9d57-664cf6b385b4%3A1709477164303%2Ca655540c-7d8f-45ff-aad2-2bb1715f7999%3A1709411055947',
#   'category': 'linear',
#   'list': [{'symbol': 'BTCUSDT',
#     'orderType': 'Market',
#     'orderLinkId': '',
#     'slLimitPrice': '0',
#     'orderId': '8753f5cb-bc2f-47d2-9d57-664cf6b385b4',
#     'cancelType': 'UNKNOWN',
#     'avgPrice': '62315.8',
#     'stopOrderType': '',
#     'lastPriceOnCreated': '62315.8',
#     'orderStatus': 'Filled',
#     'createType': 'CreateByUser',
#     'takeProfit': '',
#     'cumExecValue': '249.2632',
#     'tpslMode': '',
#     'smpType': 'None',
#     'triggerDirection': 0,
#     'blockTradeId': '',
#     'rejectReason': 'EC_NoError',
#     'isLeverage': '',
#     'price': '62628.7',
#     'orderIv': '',
#     'createdTime': '1709477164303',
#     'tpTriggerBy': '',
#     'positionIdx': 1,
#     'timeInForce': 'IOC',
#     'leavesValue': '0',
# ...
